# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#The-IMDB-dataset" data-toc-modified-id="The-IMDB-dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>The IMDB dataset</a></span></li><li><span><a href="#Loading-the-IMDB-dataset" data-toc-modified-id="Loading-the-IMDB-dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Loading the IMDB dataset</a></span><ul class="toc-item"><li><span><a href="#Sample-on-how-to-decode-reviews-back-to-English-words" data-toc-modified-id="Sample-on-how-to-decode-reviews-back-to-English-words-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Sample on how to decode reviews back to English words</a></span></li></ul></li><li><span><a href="#Preparing-the-data" data-toc-modified-id="Preparing-the-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Preparing the data</a></span><ul class="toc-item"><li><span><a href="#One-hot-Encoding-the-integer-sequences-into-a-binary-matrix" data-toc-modified-id="One-hot-Encoding-the-integer-sequences-into-a-binary-matrix-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>One-hot Encoding the integer sequences into a binary matrix</a></span></li></ul></li><li><span><a href="#Building-the-network" data-toc-modified-id="Building-the-network-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Building the network</a></span><ul class="toc-item"><li><span><a href="#The-model-definition" data-toc-modified-id="The-model-definition-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>The model definition</a></span></li><li><span><a href="#Compiling-the-model" data-toc-modified-id="Compiling-the-model-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Compiling the model</a></span></li></ul></li><li><span><a href="#Validating-our-approach" data-toc-modified-id="Validating-our-approach-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Validating our approach</a></span></li><li><span><a href="#Training-the-model" data-toc-modified-id="Training-the-model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Training the model</a></span></li><li><span><a href="#Plotting-the-training-and-validation-loss" data-toc-modified-id="Plotting-the-training-and-validation-loss-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting the training and validation loss</a></span></li><li><span><a href="#Plotting-the-training-and-validation-accuracy" data-toc-modified-id="Plotting-the-training-and-validation-accuracy-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Plotting the training and validation accuracy</a></span></li><li><span><a href="#Retraining-the-model-from-scratch" data-toc-modified-id="Retraining-the-model-from-scratch-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Retraining the model from scratch</a></span></li><li><span><a href="#Further-Experiments" data-toc-modified-id="Further-Experiments-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Further Experiments</a></span><ul class="toc-item"><li><span><a href="#Hidden-Layers" data-toc-modified-id="Hidden-Layers-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Hidden Layers</a></span><ul class="toc-item"><li><span><a href="#One-Hidden-layer" data-toc-modified-id="One-Hidden-layer-11.1.1"><span class="toc-item-num">11.1.1&nbsp;&nbsp;</span>One Hidden layer</a></span></li><li><span><a href="#Four-Hidden-Layers" data-toc-modified-id="Four-Hidden-Layers-11.1.2"><span class="toc-item-num">11.1.2&nbsp;&nbsp;</span>Four Hidden Layers</a></span></li></ul></li><li><span><a href="#Hidden-Units" data-toc-modified-id="Hidden-Units-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Hidden Units</a></span><ul class="toc-item"><li><span><a href="#32-hidden-Units" data-toc-modified-id="32-hidden-Units-11.2.1"><span class="toc-item-num">11.2.1&nbsp;&nbsp;</span>32 hidden Units</a></span></li><li><span><a href="#64-hidden-Units" data-toc-modified-id="64-hidden-Units-11.2.2"><span class="toc-item-num">11.2.2&nbsp;&nbsp;</span>64 hidden Units</a></span></li></ul></li><li><span><a href="#Loss-Function" data-toc-modified-id="Loss-Function-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Loss Function</a></span><ul class="toc-item"><li><span><a href="#Mean-Square-Error" data-toc-modified-id="Mean-Square-Error-11.3.1"><span class="toc-item-num">11.3.1&nbsp;&nbsp;</span><code>Mean Square Error</code></a></span></li></ul></li><li><span><a href="#Activation-Function" data-toc-modified-id="Activation-Function-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Activation Function</a></span><ul class="toc-item"><li><span><a href="#tanh" data-toc-modified-id="tanh-11.4.1"><span class="toc-item-num">11.4.1&nbsp;&nbsp;</span><code>tanh</code></a></span></li><li><span><a href="#selu" data-toc-modified-id="selu-11.4.2"><span class="toc-item-num">11.4.2&nbsp;&nbsp;</span><code>selu</code></a></span></li></ul></li></ul></li><li><span><a href="#Key-Takeaways" data-toc-modified-id="Key-Takeaways-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Key Takeaways</a></span></li></ul></div>

# %% [markdown]
# # Goal
# In this example, we classify movie reviews as positive or negative, based on the text content of the reviews.

# %% [markdown]
# # The IMDB dataset

# %% [markdown]
# - The IMDB dataset comes packaged with Keras. It has already been preprocessed:
#   - The reviews(sequences of words) have been turned into sequence of integers, where each integer stands for a specific word in a dictionary.

# %% [markdown]
# - This is a set of  **50,000** highly polarized reviews from the Internet Movie Database.
#   - They are split into **25,000** reviews for both training and **25,000** reviews for testing.
#   - Each set consists of $50\%$ negative and $50\%$ positive reviews.

# %% [markdown]
# # Loading the IMDB dataset

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %% [markdown]
# The argument ```num_words=10000``` means you will only keep the top 10,000 most frequently occuring words in the training data. Rare words will be discarded. This allows us to work with vector data of manageable size.

# %%
print(train_data[0])
# Out:
# [1, 13, 974, 207, 64, 110, 44, 289, 7, 5712, 299, 6548, 6339, 2, 7, 265, 3420, 31, 13, 423, 4, 85, 13, 258, 38, 38, 2, 5, 3420, 13, 43, 258, 6, 991, 146, 3521, 8, 376, 25, 15, 14, 1253, 9, 175, 227, 17, 52, 17, 4, 1596, 5, 905, 297, 4, 116, 9, 576, 565, 19, 6, 177, 15, 944, 3776, 3394, 2163, 1701, 5, 1514, 5257, 89, 70, 25, 1585, 5, 4, 653, 11, 58, 810, 272, 40, 1198, 200, 4, 2766, 5, 2, 299, 125, 1293, 17, 4, 105, 847, 44, 5, 135, 68, 3149, 411, 730, 39, 4, 229, 410, 15, 101, 337, 7, 4, 9089, 297, 80, 79, 5433, 39, 48, 335, 83, 14, 1063, 453, 13, 545, 4238, 25, 8, 106, 14, 976, 4142, 1253, 39, 9089, 8005, 3776, 3394]

# %%
train_labels[0]
# Out:
# 1

# %% [markdown]
# - Each review is a list of word indices (encoding a sequence of words).
# - Labels are lists of 0s and 1s, where 0 stands for **negative** and 1 stands for **positive**.

# %% [markdown]
# - Because we are restricting ourselves to the top 10, 000 most frequent words, no word index will exceed 10, 000:

# %%
# %%time
max([max(sequence) for sequence in train_data])
# Out:
# CPU times: user 220 ms, sys: 4 ms, total: 224 ms
# Wall time: 229 ms
# 9999

# %% [markdown]
# ## Sample on how to decode reviews back to English words

# %%
word_index = imdb.get_word_index()

# %% [markdown]
# - word_index is a dictionary mapping words to an integer index.

# %%
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])

# %% [markdown]
# - Reverses it, mapping integer indices to words.

# %%
decoded_review = ' '.join(
    [reverse_word_index.get( i - 3, '?') for i in train_data[0]])

# %% [markdown]
# - Decodes the review. Note that the indices are offset by 3 because 0, 1, and 2 are reversed indices for *padding*, *start* of sequence, and *unknown*.

# %%
decoded_review
# Out:
# "? i admit i've only seen about three of shakespeare's plays romeo juliet ? of course hamlet one i liked the other i found so so ? and hamlet i just found a masterpiece i'm pleased to tell you that this adaptation is every bit as good as the intense and dramatic play the acting is extremely strong with a cast that features kenneth branagh robin williams and billy crystal how can you lose and the change in time period looks like somewhere between the 17 and ? plays off beautifully as the characters move about and say their infamous lines straight from the script itself that any fan of the shakespearean play will get chills from if you're into this popular drama i highly urge you to watch this powerful 1996 adaptation from shakespearean admirer kenneth branagh"

# %% [markdown]
# # Preparing the data

# %% [markdown]
# - You can't feed lists of integers into a neural network. You have to turn your lists into tensors. There so tat  are two ways to do that:
#  1. Pad your lists so that they all have the same length, turn them into an integer tensor of shape ```(samples, word_indices)```, and then use as the first layer in your network a layer capable of handling such integer tensors (e.g : **[The Embedding layer](https://keras.io/layers/embeddings/)** ).
#  2. One-hot encode your lists to turn them into vectors of 0s and 1s. This would mean, for instance, turning the sequence ```[3, 5]``` into a 10, 000-dimensional vector that would be all 0s except for indices 3, and 5, which would be 1s. Then you could use as the first layer in your network a **Dense** layer, capable of handling floating-point vector data.

# %% [markdown]
# ## One-hot Encoding the integer sequences into a binary matrix

# %%
import numpy as np

# %%
def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1. # Sets specific indices of results[i] to 1s
    return results

# %%
x_train = vectorize_sequences(train_data)  # vectorized training data
x_test  = vectorize_sequences(test_data)   # vectorized testing data

# %%
x_train[0]
# Out:
# array([ 0.,  1.,  1., ...,  0.,  0.,  0.])

# %%
x_train.shape
# Out:
# (25000, 10000)

# %% [markdown]
# - Vectorize the labels, which is straightforward:

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test  = np.asarray(test_labels).astype('float32')

# %%
y_train[0]
# Out:
# 1.0

# %% [markdown]
# Now the data is ready to be fed into a neural network.

# %% [markdown]
# # Building the network

# %% [markdown]
# For time being, our network will have:
# - 2 intermediate layers with 16 hidden units each.
# - A third layer that will output the scalar prediction regarding the sentiment of the current review.

# %% [markdown]
# The intermediate layers will use ```relu``` as their activation function, and the final layer will use a sigmoid activation function so as to output a probability score.

# %% [markdown]
# ## The model definition

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# Finally, we need to choose a loss function and an optimizer. Because we are facing a binary classification problem and the output of our network is a probability (we end our network with a single-unit layer with a sigmoid activation), it is best to use the **```binary_crossentropy```** loss.
#
# It is not the only viable choice: We could use, for instance, **```mean_squared_error```**. But crossentropy is usually the best choice when you are dealing with models that output probabilities.
#
# Crossentropy is a quantity from the field of Information Theory that measures the distance between probability distributions or, in this case, between the ground-truth distribution and our predictions.

# %% [markdown]
# ## Compiling the model

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Validating our approach

# %% [markdown]
# - Create a validation set by setting apart 10, 000 samples from the original training data.

# %%
x_val = x_train[:10000]

# %%
partial_x_train = x_train[10000:]

# %%
y_val = y_train[:10000]

# %%
partial_y_train = y_train[10000:]

# %% [markdown]
# # Training the model

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 5s 349us/step - loss: 0.5433 - acc: 0.7609 - val_loss: 0.4178 - val_acc: 0.8533
# Epoch 2/20
# 15000/15000 [==============================] - 2s 143us/step - loss: 0.3214 - acc: 0.9008 - val_loss: 0.3249 - val_acc: 0.8781
# Epoch 3/20
# 15000/15000 [==============================] - 2s 134us/step - loss: 0.2304 - acc: 0.9255 - val_loss: 0.3085 - val_acc: 0.8762
# Epoch 4/20
# 15000/15000 [==============================] - 2s 154us/step - loss: 0.1806 - acc: 0.9413 - val_loss: 0.2794 - val_acc: 0.8889
# Epoch 5/20
# 15000/15000 [==============================] - 2s 150us/step - loss: 0.1459 - acc: 0.9541 - val_loss: 0.2914 - val_acc: 0.8831
# Epoch 6/20
# 15000/15000 [==============================] - 2s 149us/step - loss: 0.1179 - acc: 0.9633 - val_loss: 0.3349 - val_acc: 0.8702
# Epoch 7/20
# 15000/15000 [==============================] - 2s 153us/step - loss: 0.0973 - acc: 0.9697 - val_loss: 0.3159 - val_acc: 0.8817
# Epoch 8/20
# 15000/15000 [==============================] - 2s 152us/step - loss: 0.0798 - acc: 0.9762 - val_loss: 0.3391 - val_acc: 0.8779
# Epoch 9/20
# 15000/15000 [==============================] - 2s 149us/step - loss: 0.0655 - acc: 0.9819 - val_loss: 0.3687 - val_acc: 0.8765
# Epoch 10/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0520 - acc: 0.9863 - val_loss: 0.3942 - val_acc: 0.8715
# Epoch 11/20
# 15000/15000 [==============================] - 2s 152us/step - loss: 0.0437 - acc: 0.9903 - val_loss: 0.4215 - val_acc: 0.8716
# Epoch 12/20
# 15000/15000 [==============================] - 2s 150us/step - loss: 0.0326 - acc: 0.9942 - val_loss: 0.4570 - val_acc: 0.8677
# Epoch 13/20
# 15000/15000 [==============================] - 2s 150us/step - loss: 0.0280 - acc: 0.9948 - val_loss: 0.4887 - val_acc: 0.8666
# Epoch 14/20
# 15000/15000 [==============================] - 2s 149us/step - loss: 0.0209 - acc: 0.9971 - val_loss: 0.5204 - val_acc: 0.8664
# Epoch 15/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0176 - acc: 0.9970 - val_loss: 0.5551 - val_acc: 0.8650
# Epoch 16/20
# 15000/15000 [==============================] - 2s 148us/step - loss: 0.0143 - acc: 0.9979 - val_loss: 0.5880 - val_acc: 0.8631
# Epoch 17/20
# 15000/15000 [==============================] - 2s 154us/step - loss: 0.0081 - acc: 0.9993 - val_loss: 0.6467 - val_acc: 0.8578
# Epoch 18/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0094 - acc: 0.9988 - val_loss: 0.6697 - val_acc: 0.8606
# Epoch 19/20
# 15000/15000 [==============================] - 2s 150us/step - loss: 0.0069 - acc: 0.9990 - val_loss: 0.6950 - val_acc: 0.8595
# Epoch 20/20
# 15000/15000 [==============================] - 2s 152us/step - loss: 0.0038 - acc: 0.9997 - val_loss: 0.7853 - val_acc: 0.8570
# CPU times: user 38.5 s, sys: 6.6 s, total: 45.1 s
# Wall time: 48.1 s

# %% [markdown]
# # Plotting the training and validation loss

# %%
history_dict = history.history

# %%
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

# %%
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

# %%
epochs = range(1, len(acc_values) + 1)
epochs
# Out:
# range(1, 21)

# %%
plt.plot(epochs, loss_values, 'b', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Plotting the training and validation accuracy

# %%
plt.plot(epochs, acc_values, 'b', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# - The training loss decreases with every epoch, and the training accuracy increases with every epoch.
# - But that is not the case for the validation loss and accuracy: they seem to peak at the **4th** epoch. This is an example of **overfitting**: after the second epoch, we are overoptimizing on the training data, and we end up learning representations that are specific to the training data and don't generalize to data outside the training set.
#
# - In this case, to prevent overfitting, we could stop training after three epochs.

# %% [markdown]
# # Retraining the model from scratch

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
model.fit(x_train, y_train, epochs=3, batch_size=512)
# Out:
# Epoch 1/3
# 25000/25000 [==============================] - 3s 102us/step - loss: 0.4640 - acc: 0.8198
# Epoch 2/3
# 25000/25000 [==============================] - 2s 97us/step - loss: 0.2677 - acc: 0.9078
# Epoch 3/3
# 25000/25000 [==============================] - 2s 98us/step - loss: 0.2067 - acc: 0.9283
# CPU times: user 6.35 s, sys: 1.12 s, total: 7.46 s
# Wall time: 7.66 s

# %%
results = model.evaluate(x_test, y_test)
# Out:
# 25000/25000 [==============================] - 5s 197us/step

# %%
results
# Out:
# [0.28048378532409668, 0.88883999999999996]

# %% [markdown]
# This fairly naive approach achieves an accuracy of $88\%$.

# %% [markdown]
# # Further Experiments

# %% [markdown]
# ## Hidden Layers

# %% [markdown]
# ### One Hidden layer

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 2s 161us/step - loss: 0.5094 - acc: 0.7909 - val_loss: 0.4061 - val_acc: 0.8518
# Epoch 2/5
# 15000/15000 [==============================] - 2s 159us/step - loss: 0.3229 - acc: 0.9023 - val_loss: 0.3404 - val_acc: 0.8735
# Epoch 3/5
# 15000/15000 [==============================] - 2s 162us/step - loss: 0.2426 - acc: 0.9278 - val_loss: 0.2952 - val_acc: 0.8918
# Epoch 4/5
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.1982 - acc: 0.9403 - val_loss: 0.2980 - val_acc: 0.8819
# Epoch 5/5
# 15000/15000 [==============================] - 2s 155us/step - loss: 0.1646 - acc: 0.9517 - val_loss: 0.2815 - val_acc: 0.8875
# CPU times: user 10.1 s, sys: 1.57 s, total: 11.6 s
# Wall time: 12.1 s

# %%
def plot_history(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc_values = history_dict['acc']
    val_acc_values = history_dict['val_acc']
    epochs = range(1, len(acc_values) + 1)
    
    plt.plot(epochs, loss_values, 'b', label='Training loss')
    plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    plt.plot(epochs, acc_values, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc_values, 'r', label='Validation accuracy')
    plt.title('Training and Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# ### Four Hidden Layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 171us/step - loss: 0.5166 - acc: 0.7984 - val_loss: 0.3893 - val_acc: 0.8608
# Epoch 2/5
# 15000/15000 [==============================] - 2s 129us/step - loss: 0.2919 - acc: 0.9069 - val_loss: 0.3225 - val_acc: 0.8737
# Epoch 3/5
# 15000/15000 [==============================] - 2s 119us/step - loss: 0.2075 - acc: 0.9311 - val_loss: 0.2832 - val_acc: 0.8883
# Epoch 4/5
# 15000/15000 [==============================] - 2s 120us/step - loss: 0.1593 - acc: 0.9473 - val_loss: 0.2979 - val_acc: 0.8828
# Epoch 5/5
# 15000/15000 [==============================] - 2s 135us/step - loss: 0.1299 - acc: 0.9595 - val_loss: 0.3184 - val_acc: 0.8789
# CPU times: user 9.04 s, sys: 1.5 s, total: 10.5 s
# Wall time: 10.5 s

# %%
plot_history(history)

# %% [markdown]
# ## Hidden Units

# %% [markdown]
# ### 32 hidden Units

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 2s 145us/step - loss: 0.5005 - acc: 0.7795 - val_loss: 0.3663 - val_acc: 0.8670
# Epoch 2/5
# 15000/15000 [==============================] - 2s 126us/step - loss: 0.2805 - acc: 0.9024 - val_loss: 0.2963 - val_acc: 0.8885
# Epoch 3/5
# 15000/15000 [==============================] - 2s 136us/step - loss: 0.1977 - acc: 0.9353 - val_loss: 0.3265 - val_acc: 0.8686
# Epoch 4/5
# 15000/15000 [==============================] - 2s 134us/step - loss: 0.1523 - acc: 0.9497 - val_loss: 0.3341 - val_acc: 0.8694
# Epoch 5/5
# 15000/15000 [==============================] - 2s 142us/step - loss: 0.1227 - acc: 0.9593 - val_loss: 0.3140 - val_acc: 0.8813
# CPU times: user 9.29 s, sys: 1.52 s, total: 10.8 s
# Wall time: 10.7 s

# %%
plot_history(history)

# %% [markdown]
# ### 64 hidden Units

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 203us/step - loss: 0.4753 - acc: 0.7756 - val_loss: 0.3683 - val_acc: 0.8492
# Epoch 2/5
# 15000/15000 [==============================] - 3s 190us/step - loss: 0.2572 - acc: 0.9035 - val_loss: 0.3100 - val_acc: 0.8747
# Epoch 3/5
# 15000/15000 [==============================] - 3s 192us/step - loss: 0.1820 - acc: 0.9341 - val_loss: 0.2824 - val_acc: 0.8877
# Epoch 4/5
# 15000/15000 [==============================] - 3s 178us/step - loss: 0.1413 - acc: 0.9497 - val_loss: 0.3197 - val_acc: 0.8804
# Epoch 5/5
# 15000/15000 [==============================] - 3s 178us/step - loss: 0.1008 - acc: 0.9649 - val_loss: 0.3692 - val_acc: 0.8688
# CPU times: user 9.29 s, sys: 5.21 s, total: 14.5 s
# Wall time: 14.4 s

# %%
plot_history(history)

# %% [markdown]
# ## Loss Function

# %% [markdown]
# ### ```Mean Square Error```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='mse',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 197us/step - loss: 0.1577 - acc: 0.7941 - val_loss: 0.1116 - val_acc: 0.8617
# Epoch 2/5
# 15000/15000 [==============================] - 2s 155us/step - loss: 0.0803 - acc: 0.9084 - val_loss: 0.0869 - val_acc: 0.8861
# Epoch 3/5
# 15000/15000 [==============================] - 2s 157us/step - loss: 0.0559 - acc: 0.9337 - val_loss: 0.1018 - val_acc: 0.8615
# Epoch 4/5
# 15000/15000 [==============================] - 2s 149us/step - loss: 0.0425 - acc: 0.9509 - val_loss: 0.1287 - val_acc: 0.8266
# Epoch 5/5
# 15000/15000 [==============================] - 2s 146us/step - loss: 0.0351 - acc: 0.9606 - val_loss: 0.0879 - val_acc: 0.8811
# CPU times: user 9.14 s, sys: 3.34 s, total: 12.5 s
# Wall time: 12.5 s

# %%
plot_history(history)

# %% [markdown]
# ## Activation Function

# %% [markdown]
# ### ```tanh```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='tanh', input_shape=(10000, )))
model.add(layers.Dense(32, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 209us/step - loss: 0.4501 - acc: 0.7999 - val_loss: 0.3191 - val_acc: 0.8729
# Epoch 2/5
# 15000/15000 [==============================] - 3s 180us/step - loss: 0.2326 - acc: 0.9145 - val_loss: 0.3696 - val_acc: 0.8480
# Epoch 3/5
# 15000/15000 [==============================] - 3s 173us/step - loss: 0.1661 - acc: 0.9389 - val_loss: 0.3210 - val_acc: 0.8750
# Epoch 4/5
# 15000/15000 [==============================] - 3s 195us/step - loss: 0.1225 - acc: 0.9552 - val_loss: 0.3267 - val_acc: 0.8801
# Epoch 5/5
# 15000/15000 [==============================] - 2s 165us/step - loss: 0.1064 - acc: 0.9610 - val_loss: 0.3827 - val_acc: 0.8707
# CPU times: user 8.94 s, sys: 5.22 s, total: 14.2 s
# Wall time: 14.1 s

# %%
plot_history(history)

# %% [markdown]
# ### ```selu```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='selu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='selu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 3s 169us/step - loss: 0.4619 - acc: 0.7917 - val_loss: 0.3190 - val_acc: 0.8753
# Epoch 2/5
# 15000/15000 [==============================] - 2s 144us/step - loss: 0.2502 - acc: 0.9012 - val_loss: 0.3025 - val_acc: 0.8730
# Epoch 3/5
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.1751 - acc: 0.9344 - val_loss: 0.3612 - val_acc: 0.8620
# Epoch 4/5
# 15000/15000 [==============================] - 2s 147us/step - loss: 0.1368 - acc: 0.9485 - val_loss: 0.3217 - val_acc: 0.8795
# Epoch 5/5
# 15000/15000 [==============================] - 2s 152us/step - loss: 0.0967 - acc: 0.9660 - val_loss: 0.3824 - val_acc: 0.8725
# CPU times: user 9.75 s, sys: 1.71 s, total: 11.5 s
# Wall time: 11.7 s

# %%
plot_history(history)

# %% [markdown]
# # Key Takeaways

# %% [markdown]
# 1. You usually need to do quite a bit of preprocessing on your raw data in order to be able to feed it--as tensors-- into a neural network. Sequences of words can be encoded as binary vectors, but there are other encoding options, too.
# 2. Stacks of **Dense** layers with **relu** activation can solve a wide range of problems (including sentiment classification), and you will likely use them frequently.
# 3. In a binary classification problem (two output classes), your network should end with a Dense layer with one unit and a sigmoid activation: the output of your network should be a scalar between 0 and 1, encoding a probability.
# 4. With such a scalar sigmoid output on a binary classification, the loss function you should use is **binary_crossentropy**.
# 5.  The **rmsprop** optimizer is generally a good choice, whatever your problem. That is one less thing to worry about.
# 6. As they get better at their training data, neural networks eventually start over-fitting and end up obtaining increasingly worse results on data they have never seen before.

# %%
# %load_ext version_information
# %version_information keras, numpy, matplotlib
# Out:
# Software versions
# Python 3.6.3 64bit [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]
# IPython 6.2.1
# OS Linux 4.4.0 53 generic x86_64 with debian stretch sid
# keras 2.0.9
# numpy 1.12.1
# matplotlib 2.0.0
# Sat Dec 16 19:01:17 2017 CST
